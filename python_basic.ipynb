# %%
print(10)
# Out:
# 10

# %%
print("kumar")
# Out:
# kumar

# %%
print(10+5)
# Out:
# 15

# %%
"kumar"
# Out:
# 'kumar'

# %%
a = 10.25/5

# %%
print(a)
# Out:
# 2.05

# %%
id(a)
# Out:
# 2318437411664

# %%
print("Helo world")
# Out:
# Helo world

# %%
10.25/5
# Out:
# 2.05

# %%
a
# Out:
# 2.05

# %%
a = 10+8

# %%
print(a)
# Out:
# 18

# %%
id(a)
# Out:
# 2318437411664

# %%
a = input("Enter a number")
b = input("Enter 2nd number")
c = a + b
# Out:
# Enter a number10
# Enter 2nd number5

# %%
print(c)
# Out:
# 105

# %%
a = input("num1")
b = input("num2")
# Out:
# num120
# num223

# %%
print(10)
# Out:
# 10

# %%
print("python")
# Out:
# python

# %%
# variable ---

# %%
variable = 10+74

# %%
variable
# Out:
# 84

# %%
print(variable)
# Out:
# 84

# %%
a
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [9], in <cell line: 1>()
# ----> 1 a
#
# NameError: name 'a' is not defined

# %%
# print()

# %%
print(56)
# Out:
# 56

# %%
''' my name is kumar

python
ML  '''
# Out:
# ' my name is kumar '

# %%
10
# Out:
# 10

# %%
a = 10

# %%
a
# Out:
# 10

# %%
print(a)
# Out:
# 10

# %%
None  =  10
# Out:
#   Input In [20]
#     None  =  10
#     ^
# SyntaxError: cannot assign to None

# %%
def = 10
# Out:
#   Input In [21]
#     def = 10
#         ^
# SyntaxError: invalid syntax

# %%
import = 10
# Out:
#   Input In [22]
#     import = 10
#            ^
# SyntaxError: invalid syntax

# %%
impor = 10

# %%
impor
# Out:
# 10

# %%
a = 'python'

# %%
b= "python"

# %%
c = '''python'''

# %%
print(a)
print(b)
print(c)
# Out:
# python
# python
# python

# %%
1.
A variable name must be starts from a alphabetic letter or an underscore(_).

2.
A variable name can't be starts with a special character or with a digit.

3.
A variable name can't contains any whitespace.

4.
A variable name can't be same as a keyword.

# %%
_a = 50

# %%
@b = 50
# Out:
#   Input In [31]
#     @b = 50
#        ^
# SyntaxError: invalid syntax

# %%
1abc = 50
# Out:
#   Input In [32]
#     1abc = 50
#      ^
# SyntaxError: invalid syntax

# %%
a_c = 10

# %%
1@h = 20
# Out:
#   Input In [35]
#     1@h = 20
#     ^
# SyntaxError: cannot assign to operator

# %%
mycoursenameispython = 20

# %%
mycoursenameispython
# Out:
# 20

# %%
num = 10.2

# %%
# add
add = 10 + 5

# %%
print(add)
# Out:
# 15

# %%
# sub
sub = 50 - 10

# %%
print(sub)
# Out:
# 40

# %%
# Multiple

# %%
mul = 12 * 5

# %%
print(mul)
# Out:
# 60

# %%
# devided

# %%
dev = 10/5

# %%
print(dev)
# Out:
# 2.0

# %%
10%5
# Out:
# 0

# %%
exp = 2**2

# %%
exp
# Out:
# 4

# %%
2**2
# Out:
# 4

# %%
10//5
# Out:
# 2

# %%
10%2
# Out:
# 0

# %%
11%5
# Out:
# 1

# %%
15%2
# Out:
# 1

# %%
15/2
# Out:
# 7.5

# %%
15//2
# Out:
# 7

# %%
result = 1 + 2 * 3 / 4 ** 2

# %%
print(result)
# Out:
# 1.375

# %%
id(result)
# Out:
# 2257220102736

# %%
result = 10
